# %% [markdown]
# ## Plot the sky on a given day

# %%
import plot as p
p.sky_1day('2023/11/30', focalplane=True, Az=320, El=50, Bs=0)

# %% [markdown]
# ## Plot the sky at a given time. Angles between boresight and sun/gantry are showed

# %%
p.plot_sky('2023/11/30/1/0', focalplane=True, Az=320, El=50, exclude=["Gantry"])

# %%
p.plot_sky('2023/11/30/13/30', focalplane=True, Az=300, El=70, r=1) # r=1 means gantry is fully moved to the end of the rail

# %% [markdown]
# # Plot the skies over a certain time range

# %%
p.plot_timestream('2023/11/30/15/0', '2023/11/30/17/0', 15, focalplane=True, Az=83, El=60, save=True, foldername='231130', filename='1518')

# %% [markdown]
# ## Sun and Moon angles over a certain time range

# %%
import sun
sun.plot_sun_angles(Az=60, El=60, start='2023/11/29/8/0', end='2023/11/30/8/0', delta=5, thre=45)
# Out:
# 45 deg threshold: 08:45, 14:35

# %%
import moon
moon.plot_moon_angles(Az=60, El=60, start='2023/11/29/8/0', end='2023/11/30/8/0', delta=5, thre=45)
# Out:
# 45 deg threshold: 00:10, 04:10

# %% [markdown]
# ## Availability of sources

# %%
import sources
sources.plot_sources_angles(start='2023/11/29/0/0', end='2024/5/30/8/0', thre=49)

# %% [markdown]
# ## Other modules

# %%
import structures as st

gt = st.Gantry()
gs = st.GroundScreen()
st.plot_points([gt.points, gs.points])

# %%
import datetime as dt
from zoneinfo import ZoneInfo
import planets as pl
import numpy as np

CHILE = ZoneInfo("America/Santiago")
time = dt.datetime(2023, 11, 28, 12, 0, tzinfo=CHILE)

pls = pl.Planets(time)
print(pls.Sun.el)
# Out:
# 71.64324756285443

# %%
import focal_plane as fp

FP = fp.FocalPlane(Az=0, El=40, Bs=20)
FP.plot_fp()
